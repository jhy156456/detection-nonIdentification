# %%
print("test")
# Out:
# test

# %%
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# 동영상 파일 사용시
# video_path = "path/to/your/video/file.mp4"
# cap = cv2.VideoCapture(video_path)

# webcam 사용시`
cap = cv2.VideoCapture(0)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 53.7ms
# Speed: 3.5ms preprocess, 53.7ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 43.5ms
# Speed: 1.6ms preprocess, 43.5ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 43.2ms
# Speed: 1.4ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 50.0ms
# Speed: 1.7ms preprocess, 50.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 46.7ms
# Speed: 1.5ms preprocess, 46.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 4 books, 48.2ms
# Speed: 1.5ms preprocess, 48.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.9ms
# Speed: 1.7ms preprocess, 46.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 4 books, 44.8ms
# Speed: 1.4ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.3ms
# Speed: 1.5ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 45.6ms
# Speed: 1.8ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 5 books, 44.5ms
# Speed: 1.6ms preprocess, 44.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.6ms
# Speed: 2.0ms preprocess, 46.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.8ms
# Speed: 1.8ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 40.9ms
# Speed: 1.6ms preprocess, 40.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 43.3ms
# Speed: 1.7ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 4 books, 43.1ms
# Speed: 1.8ms preprocess, 43.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 7 books, 42.8ms
# Speed: 1.6ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 41.4ms
# Speed: 1.5ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 44.7ms
# Speed: 1.9ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 4 books, 42.7ms
# Speed: 1.7ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 42.4ms
# Speed: 1.6ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 4 books, 42.2ms
# Speed: 2.0ms preprocess, 42.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 43.1ms
# Speed: 1.9ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 45.4ms
# Speed: 1.7ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 4 books, 44.5ms
# Speed: 1.6ms preprocess, 44.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.1ms
# Speed: 1.6ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 48.4ms
# Speed: 1.6ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 4 books, 45.0ms
# Speed: 1.5ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 41.8ms
# Speed: 1.4ms preprocess, 41.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 5 books, 43.5ms
# Speed: 2.0ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 43.7ms
# Speed: 1.7ms preprocess, 43.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 7 books, 43.6ms
# Speed: 1.9ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 45.4ms
# Speed: 1.8ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 44.7ms
# Speed: 1.4ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 45.2ms
# Speed: 1.5ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 44.1ms
# Speed: 1.4ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 43.5ms
# Speed: 1.8ms preprocess, 43.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 5 books, 42.9ms
# Speed: 1.4ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 4 books, 45.6ms
# Speed: 1.7ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 44.0ms
# Speed: 1.9ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.7ms
# Speed: 1.5ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.2ms
# Speed: 1.7ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 6 books, 44.5ms
# Speed: 1.5ms preprocess, 44.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 49.1ms
# Speed: 1.6ms preprocess, 49.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 43.8ms
# Speed: 1.6ms preprocess, 43.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 45.0ms
# Speed: 1.6ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 45.3ms
# Speed: 1.6ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 43.9ms
# Speed: 1.7ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 5 books, 48.4ms
# Speed: 1.5ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 42.7ms
# Speed: 2.0ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 43.1ms
# Speed: 2.1ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 44.3ms
# Speed: 1.5ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 43.4ms
# Speed: 2.1ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 48.3ms
# Speed: 1.8ms preprocess, 48.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 7 books, 44.4ms
# Speed: 2.2ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 45.5ms
# Speed: 1.8ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 46.3ms
# Speed: 2.1ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 45.0ms
# Speed: 1.9ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.0ms
# Speed: 1.9ms preprocess, 46.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 48.0ms
# Speed: 1.5ms preprocess, 48.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.8ms
# Speed: 1.6ms preprocess, 46.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.7ms
# Speed: 1.7ms preprocess, 46.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 45.6ms
# Speed: 1.4ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 49.3ms
# Speed: 2.1ms preprocess, 49.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 4 books, 44.1ms
# Speed: 2.1ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 5 books, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 4 books, 45.3ms
# Speed: 1.9ms preprocess, 45.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 4 books, 43.3ms
# Speed: 2.0ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 7 books, 43.1ms
# Speed: 1.9ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 45.3ms
# Speed: 1.9ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 45.2ms
# Speed: 1.4ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 43.6ms
# Speed: 1.6ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 6 books, 44.9ms
# Speed: 2.2ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 43.6ms
# Speed: 1.6ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 45.3ms
# Speed: 2.1ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 41.3ms
# Speed: 1.6ms preprocess, 41.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 7 books, 44.8ms
# Speed: 2.1ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 45.3ms
# Speed: 2.0ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 47.4ms
# Speed: 1.9ms preprocess, 47.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 42.4ms
# Speed: 2.1ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 44.7ms
# Speed: 1.6ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 5 books, 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 47.1ms
# Speed: 1.7ms preprocess, 47.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.3ms
# Speed: 1.5ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 7 books, 45.3ms
# Speed: 1.9ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 45.5ms
# Speed: 1.8ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 49.6ms
# Speed: 1.7ms preprocess, 49.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 45.2ms
# Speed: 2.1ms preprocess, 45.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 43.4ms
# Speed: 2.1ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 44.9ms
# Speed: 2.2ms preprocess, 44.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 45.5ms
# Speed: 1.8ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 7 books, 45.7ms
# Speed: 1.9ms preprocess, 45.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.4ms
# Speed: 2.1ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 43.9ms
# Speed: 1.6ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 5 books, 44.7ms
# Speed: 2.0ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 47.0ms
# Speed: 2.1ms preprocess, 47.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 7 books, 45.6ms
# Speed: 1.8ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 7 books, 44.1ms
# Speed: 1.7ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 7 books, 44.9ms
# Speed: 1.4ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 46.1ms
# Speed: 1.7ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 45.9ms
# Speed: 1.4ms preprocess, 45.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 4 books, 46.3ms
# Speed: 1.8ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 44.5ms
# Speed: 1.7ms preprocess, 44.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 47.8ms
# Speed: 1.6ms preprocess, 47.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 5 books, 44.0ms
# Speed: 2.1ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 7 books, 46.0ms
# Speed: 2.1ms preprocess, 46.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 45.4ms
# Speed: 2.0ms preprocess, 45.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.9ms
# Speed: 1.6ms preprocess, 46.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.4ms
# Speed: 1.4ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 44.3ms
# Speed: 1.7ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 7 books, 45.3ms
# Speed: 2.0ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.3ms
# Speed: 2.0ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 44.6ms
# Speed: 1.4ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 4 books, 49.0ms
# Speed: 1.7ms preprocess, 49.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 4 books, 45.0ms
# Speed: 1.6ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 45.3ms
# Speed: 1.5ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 44.4ms
# Speed: 1.8ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.2ms
# Speed: 1.8ms preprocess, 46.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 45.3ms
# Speed: 1.8ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 7 books, 44.9ms
# Speed: 2.0ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.8ms
# Speed: 1.9ms preprocess, 46.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 7 books, 43.6ms
# Speed: 1.7ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 7 books, 46.1ms
# Speed: 2.1ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 44.2ms
# Speed: 1.4ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 46.5ms
# Speed: 1.5ms preprocess, 46.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 43.6ms
# Speed: 1.9ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 4 books, 44.2ms
# Speed: 1.7ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 47.1ms
# Speed: 1.4ms preprocess, 47.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 5 books, 45.6ms
# Speed: 1.5ms preprocess, 45.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 45.2ms
# Speed: 1.6ms preprocess, 45.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 6 books, 43.0ms
# Speed: 1.5ms preprocess, 43.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.6ms
# Speed: 2.1ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 45.5ms
# Speed: 1.8ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 4 books, 45.6ms
# Speed: 2.2ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 7 books, 46.1ms
# Speed: 1.5ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.0ms
# Speed: 1.7ms preprocess, 46.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.0ms
# Speed: 1.5ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 7 books, 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.2ms
# Speed: 2.0ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 42.8ms
# Speed: 1.7ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 44.3ms
# Speed: 1.7ms preprocess, 44.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.1ms
# Speed: 1.5ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 44.7ms
# Speed: 2.1ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 42.8ms
# Speed: 1.8ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.4ms
# Speed: 2.0ms preprocess, 46.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 45.0ms
# Speed: 1.7ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 5 books, 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.6ms
# Speed: 2.1ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 4 books, 46.1ms
# Speed: 1.7ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 4 books, 44.5ms
# Speed: 1.5ms preprocess, 44.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 43.3ms
# Speed: 1.5ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.2ms
# Speed: 1.6ms preprocess, 46.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 46.9ms
# Speed: 1.7ms preprocess, 46.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.6ms
# Speed: 1.6ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bottles, 2 beds, 6 books, 46.1ms
# Speed: 2.0ms preprocess, 46.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 45.4ms
# Speed: 2.0ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 42.5ms
# Speed: 2.1ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 45.2ms
# Speed: 1.7ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.4ms
# Speed: 1.7ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 43.1ms
# Speed: 1.6ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 43.4ms
# Speed: 2.1ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 44.3ms
# Speed: 1.5ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 7 books, 45.6ms
# Speed: 1.9ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 5 books, 44.5ms
# Speed: 2.1ms preprocess, 44.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 7 books, 44.1ms
# Speed: 1.9ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 4 books, 44.6ms
# Speed: 1.7ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.1ms
# Speed: 1.5ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 2 beds, 6 books, 44.6ms
# Speed: 2.0ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 43.3ms
# Speed: 1.6ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 2 beds, 6 books, 44.0ms
# Speed: 1.9ms preprocess, 44.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bottle, 1 bed, 7 books, 45.0ms
# Speed: 1.6ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 bed, 6 books, 45.2ms
# Speed: 1.6ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bottles, 1 bed, 6 books, 44.8ms
# Speed: 1.4ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 44.4ms
# Speed: 2.0ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 6 books, 45.0ms
# Speed: 1.9ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 6 books, 46.2ms
# Speed: 1.7ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 6 books, 47.0ms
# Speed: 1.4ms preprocess, 47.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 6 books, 48.7ms
# Speed: 1.5ms preprocess, 48.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.8ms
# Speed: 1.8ms preprocess, 46.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 46.9ms
# Speed: 2.0ms preprocess, 46.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 beds, 4 books, 46.1ms
# Speed: 2.0ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 45.2ms
# Speed: 1.7ms preprocess, 45.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 5 books, 44.1ms
# Speed: 1.7ms preprocess, 44.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 42.7ms
# Speed: 2.1ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 44.4ms
# Speed: 2.2ms preprocess, 44.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 5 books, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 44.8ms
# Speed: 1.9ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 43.1ms
# Speed: 2.1ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 46.3ms
# Speed: 2.0ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 43.0ms
# Speed: 1.6ms preprocess, 43.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 44.6ms
# Speed: 1.6ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 44.8ms
# Speed: 1.7ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 43.3ms
# Speed: 1.7ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 43.9ms
# Speed: 1.6ms preprocess, 43.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 49.1ms
# Speed: 1.5ms preprocess, 49.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 46.9ms
# Speed: 2.0ms preprocess, 46.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 46.1ms
# Speed: 1.8ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 42.3ms
# Speed: 1.8ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 5 books, 45.2ms
# Speed: 1.8ms preprocess, 45.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 42.7ms
# Speed: 1.7ms preprocess, 42.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 44.6ms
# Speed: 2.1ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 44.1ms
# Speed: 2.1ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 46.1ms
# Speed: 1.7ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 1 remote, 4 books, 43.2ms
# Speed: 1.6ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 45.1ms
# Speed: 1.7ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 beds, 5 books, 44.6ms
# Speed: 1.5ms preprocess, 44.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.9ms
# Speed: 1.9ms preprocess, 45.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 43.2ms
# Speed: 2.2ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 45.3ms
# Speed: 1.7ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 44.3ms
# Speed: 1.6ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 44.2ms
# Speed: 1.7ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 43.5ms
# Speed: 1.6ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 43.5ms
# Speed: 1.6ms preprocess, 43.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 42.3ms
# Speed: 1.9ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.2ms
# Speed: 1.9ms preprocess, 45.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 3 books, 45.3ms
# Speed: 1.6ms preprocess, 45.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.1ms
# Speed: 2.0ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 3 books, 46.1ms
# Speed: 2.1ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.2ms
# Speed: 1.4ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 45.4ms
# Speed: 1.5ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 43.4ms
# Speed: 2.0ms preprocess, 43.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 44.1ms
# Speed: 1.8ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.6ms
# Speed: 1.7ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 47.9ms
# Speed: 1.7ms preprocess, 47.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 43.3ms
# Speed: 1.7ms preprocess, 43.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 43.9ms
# Speed: 1.5ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.2ms
# Speed: 2.0ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 42.6ms
# Speed: 1.5ms preprocess, 42.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.6ms
# Speed: 2.2ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.1ms
# Speed: 1.6ms preprocess, 45.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.2ms
# Speed: 1.5ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 45.1ms
# Speed: 1.5ms preprocess, 45.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 47.9ms
# Speed: 1.7ms preprocess, 47.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.6ms
# Speed: 1.8ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 46.8ms
# Speed: 1.8ms preprocess, 46.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 44.6ms
# Speed: 1.9ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 46.4ms
# Speed: 1.8ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.9ms
# Speed: 2.0ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.3ms
# Speed: 1.6ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.4ms
# Speed: 1.9ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.3ms
# Speed: 2.1ms preprocess, 44.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.0ms
# Speed: 2.2ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.3ms
# Speed: 1.5ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 46.6ms
# Speed: 1.6ms preprocess, 46.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 46.4ms
# Speed: 2.0ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 45.0ms
# Speed: 1.6ms preprocess, 45.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.7ms
# Speed: 2.0ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 43.2ms
# Speed: 2.0ms preprocess, 43.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 47.5ms
# Speed: 2.0ms preprocess, 47.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 48.3ms
# Speed: 2.1ms preprocess, 48.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.5ms
# Speed: 1.5ms preprocess, 46.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 43.1ms
# Speed: 2.2ms preprocess, 43.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.6ms
# Speed: 1.8ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 47.0ms
# Speed: 1.5ms preprocess, 47.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.8ms
# Speed: 1.9ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 45.2ms
# Speed: 1.6ms preprocess, 45.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.5ms
# Speed: 1.6ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.8ms
# Speed: 1.6ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.0ms
# Speed: 2.0ms preprocess, 45.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.1ms
# Speed: 2.0ms preprocess, 45.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.1ms
# Speed: 1.4ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.6ms
# Speed: 1.9ms preprocess, 44.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 44.5ms
# Speed: 1.3ms preprocess, 44.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.9ms
# Speed: 1.5ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.4ms
# Speed: 1.9ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.7ms
# Speed: 1.9ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.3ms
# Speed: 1.5ms preprocess, 45.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.7ms
# Speed: 2.2ms preprocess, 46.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.4ms
# Speed: 1.4ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 43.6ms
# Speed: 1.5ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 42.9ms
# Speed: 1.5ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 42.3ms
# Speed: 2.1ms preprocess, 42.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.2ms
# Speed: 2.0ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.2ms
# Speed: 1.6ms preprocess, 46.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.4ms
# Speed: 1.4ms preprocess, 46.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.1ms
# Speed: 1.6ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.7ms
# Speed: 1.6ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 44.8ms
# Speed: 1.9ms preprocess, 44.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 42.5ms
# Speed: 1.7ms preprocess, 42.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 42.0ms
# Speed: 2.3ms preprocess, 42.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 47.1ms
# Speed: 2.2ms preprocess, 47.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.4ms
# Speed: 1.8ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 43.8ms
# Speed: 1.5ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.4ms
# Speed: 1.6ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.4ms
# Speed: 1.5ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.5ms
# Speed: 1.6ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.4ms
# Speed: 1.4ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 43.7ms
# Speed: 1.5ms preprocess, 43.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 44.7ms
# Speed: 1.5ms preprocess, 44.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 43.3ms
# Speed: 1.6ms preprocess, 43.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 45.6ms
# Speed: 1.9ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 43.6ms
# Speed: 1.9ms preprocess, 43.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.1ms
# Speed: 2.2ms preprocess, 44.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.5ms
# Speed: 2.1ms preprocess, 44.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.2ms
# Speed: 1.6ms preprocess, 45.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.4ms
# Speed: 1.7ms preprocess, 45.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 42.4ms
# Speed: 1.5ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 46.6ms
# Speed: 1.5ms preprocess, 46.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 47.3ms
# Speed: 1.5ms preprocess, 47.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 3 books, 44.4ms
# Speed: 1.7ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 42.4ms
# Speed: 1.7ms preprocess, 42.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 42.7ms
# Speed: 2.0ms preprocess, 42.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.4ms
# Speed: 1.5ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.0ms
# Speed: 2.1ms preprocess, 46.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.4ms
# Speed: 2.2ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 43.6ms
# Speed: 2.1ms preprocess, 43.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.9ms
# Speed: 1.4ms preprocess, 44.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 43.9ms
# Speed: 1.8ms preprocess, 43.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.2ms
# Speed: 1.9ms preprocess, 45.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 43.9ms
# ...
#
# 0: 384x640 1 person, 1 bed, 4 books, 44.7ms
# Speed: 1.7ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 5 books, 47.5ms
# Speed: 2.0ms preprocess, 47.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 47.8ms
# Speed: 1.7ms preprocess, 47.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 50.8ms
# Speed: 1.6ms preprocess, 50.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 48.6ms
# Speed: 1.5ms preprocess, 48.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 47.1ms
# Speed: 1.6ms preprocess, 47.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 5 books, 47.6ms
# Speed: 2.0ms preprocess, 47.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 48.0ms
# Speed: 2.2ms preprocess, 48.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 chairs, 1 bed, 4 books, 46.6ms
# Speed: 1.5ms preprocess, 46.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 44.7ms
# Speed: 2.2ms preprocess, 44.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 45.7ms
# Speed: 1.5ms preprocess, 45.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 54.1ms
# Speed: 1.6ms preprocess, 54.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 51.8ms
# Speed: 1.7ms preprocess, 51.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 47.7ms
# Speed: 1.9ms preprocess, 47.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 47.2ms
# Speed: 2.2ms preprocess, 47.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 49.5ms
# Speed: 2.2ms preprocess, 49.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.3ms
# Speed: 1.7ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 47.2ms
# Speed: 1.4ms preprocess, 47.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 chairs, 1 bed, 5 books, 45.8ms
# Speed: 1.9ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.1ms
# Speed: 2.0ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 48.4ms
# Speed: 1.5ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 45.5ms
# Speed: 2.1ms preprocess, 45.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.1ms
# Speed: 2.0ms preprocess, 46.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 chairs, 1 bed, 5 books, 48.4ms
# Speed: 2.2ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 48.6ms
# Speed: 2.1ms preprocess, 48.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 44.6ms
# Speed: 1.4ms preprocess, 44.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 48.1ms
# Speed: 2.0ms preprocess, 48.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 48.3ms
# Speed: 1.3ms preprocess, 48.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 51.9ms
# Speed: 1.8ms preprocess, 51.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.6ms
# Speed: 1.7ms preprocess, 46.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 45.6ms
# Speed: 1.6ms preprocess, 45.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 49.4ms
# Speed: 2.0ms preprocess, 49.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.6ms
# Speed: 1.9ms preprocess, 46.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 46.3ms
# Speed: 1.6ms preprocess, 46.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 45.6ms
# Speed: 1.7ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 chairs, 1 bed, 4 books, 46.1ms
# Speed: 1.8ms preprocess, 46.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 43.8ms
# Speed: 1.7ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 44.4ms
# Speed: 1.6ms preprocess, 44.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 48.4ms
# Speed: 1.5ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 5 books, 51.5ms
# Speed: 2.0ms preprocess, 51.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 49.4ms
# Speed: 1.6ms preprocess, 49.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 48.7ms
# Speed: 1.7ms preprocess, 48.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 46.9ms
# Speed: 1.5ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 47.2ms
# Speed: 1.5ms preprocess, 47.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 48.4ms
# Speed: 1.7ms preprocess, 48.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 6 books, 45.6ms
# Speed: 2.2ms preprocess, 45.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 46.7ms
# Speed: 1.5ms preprocess, 46.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 6 books, 46.5ms
# Speed: 1.7ms preprocess, 46.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 3 books, 47.2ms
# Speed: 1.7ms preprocess, 47.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 4 books, 44.0ms
# Speed: 1.7ms preprocess, 44.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 6 books, 46.9ms
# Speed: 1.9ms preprocess, 46.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 44.2ms
# Speed: 2.0ms preprocess, 44.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 43.2ms
# Speed: 1.7ms preprocess, 43.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bed, 4 books, 50.2ms
# Speed: 1.7ms preprocess, 50.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 43.8ms
# Speed: 1.7ms preprocess, 43.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 chair, 1 bed, 5 books, 46.6ms
# Speed: 1.7ms preprocess, 46.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 21
#      17 success, frame = cap.read()
#      19 if success:
#      20     # Run YOLOv8 inference on the frame
# ---> 21     results = model(frame)
#      23     # Visualize the results on the frame
#      24     annotated_frame = results[0].plot()
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/yolo/engine/model.py:111, in YOLO.__call__(self, source, stream, **kwargs)
#     109 def __call__(self, source=None, stream=False, **kwargs):
#     110     """Calls the 'predict' function with given arguments to perform object detection."""
# --> 111     return self.predict(source, stream, **kwargs)
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/yolo/engine/model.py:255, in YOLO.predict(self, source, stream, **kwargs)
#     253     if 'project' in overrides or 'name' in overrides:
#     254         self.predictor.save_dir = self.predictor.get_save_dir()
# --> 255 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/yolo/engine/predictor.py:188, in BasePredictor.__call__(self, source, model, stream)
#     186     return self.stream_inference(source, model)
#     187 else:
# --> 188     return list(self.stream_inference(source, model))
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/utils/_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/yolo/engine/predictor.py:244, in BasePredictor.stream_inference(self, source, model)
#     242 # Inference
#     243 with profilers[1]:
# --> 244     preds = self.model(im, augment=self.args.augment, visualize=visualize)
#     246 # Postprocess
#     247 with profilers[2]:
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/autobackend.py:314, in AutoBackend.forward(self, im, augment, visualize)
#     311     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     313 if self.pt or self.nn_module:  # PyTorch
# --> 314     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     315 elif self.jit:  # TorchScript
#     316     y = self.model(im)
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/tasks.py:45, in BaseModel.forward(self, x, *args, **kwargs)
#      43 if isinstance(x, dict):  # for cases of training and validating while training.
#      44     return self.loss(x, *args, **kwargs)
# ---> 45 return self.predict(x, *args, **kwargs)
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/tasks.py:62, in BaseModel.predict(self, x, profile, visualize, augment)
#      60 if augment:
#      61     return self._predict_augment(x)
# ---> 62 return self._predict_once(x, profile, visualize)
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/tasks.py:82, in BaseModel._predict_once(self, x, profile, visualize)
#      80 if profile:
#      81     self._profile_one_layer(m, x, dt)
# ---> 82 x = m(x)  # run
#      83 y.append(x if m.i in self.save else None)  # save output
#      84 if visualize:
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:181, in C2f.forward(self, x)
#     179 """Forward pass through C2f layer."""
#     180 y = list(self.cv1(x).chunk(2, 1))
# --> 181 y.extend(m(y[-1]) for m in self.m)
#     182 return self.cv2(torch.cat(y, 1))
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:181, in <genexpr>(.0)
#     179 """Forward pass through C2f layer."""
#     180 y = list(self.cv1(x).chunk(2, 1))
# --> 181 y.extend(m(y[-1]) for m in self.m)
#     182 return self.cv2(torch.cat(y, 1))
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/envs/yolov8/lib/python3.9/site-packages/ultralytics/nn/modules/block.py:283, in Bottleneck.forward(self, x)
#     281 def forward(self, x):
#     282     """'forward()' applies the YOLOv5 FPN to input data."""
# --> 283     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# KeyboardInterrupt:
